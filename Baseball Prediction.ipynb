# %%
import pandas as pd

# %%
df = pd.read_csv('new_2025_mlb_dataset.csv', encoding = 'latin-1')

# %%
X = df.iloc[:, 0:15]

# %%
y = df.iloc[:, 15]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state =17, test_size = 0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
rf.score(X_test, y_test)
# Out:
# 0.5728155339805825

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
print("hello world")
# Out:
# hello world

# %%
df.head()
# Out:
#    home_win_pct  home_obp  home_home_runs  home_ops  home_era  home_whip  \
# 0      1.000000     0.435            11.0     1.290      3.50       1.44
# 1      0.500000     0.258             3.0     0.625      1.00       1.06
# 2      1.000000     0.387             2.0     0.833      2.00       0.78
# 3      0.333333     0.354             2.0     0.750      7.67       1.44
# 4      0.000000     0.313             4.0     0.757      8.05       1.89
#
#    home_strikeouts  away_win_pct  away_obp  away_home_runs  away_ops  \
# 0             22.0      0.000000     0.326             2.0     0.703
# 1             17.0      0.500000     0.282             1.0     0.548
# 2             14.0      0.000000     0.209             1.0     0.475
# 3             26.0      0.666667     0.350            10.0     0.956
# 4             24.0      1.000000     0.400             5.0     0.966
#
#    away_era  away_whip  away_strikeouts  is_home  game_winner
# ...

# %%
probabilities = rf.predict_proba(X_test)

# %%
split_index = int(.8 * len(df))

# %%
new_X_train = X.iloc[:split_index]

# %%
new_X_test = X.iloc[split_index:]

# %%
new_y_train = y.iloc[:split_index]
new_y_test = y.iloc[split_index:]

# %%
new_rf = RandomForestClassifier()

# %%
new_rf.fit(new_X_train, new_y_train)
# Out:
# RandomForestClassifier()

# %%
y_new_pred = new_rf.predict(new_X_test)

# %%
new_rf.score(new_X_test, new_y_test)
# Out:
# 0.5760517799352751

# %%
# import the rf model. 
import joblib

# %%
joblib.dump(new_rf, 'mlb_rf_model.pkl')
# Out:
# ['mlb_rf_model.pkl']
